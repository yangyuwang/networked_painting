# %%
from FaceImageNet import FaceImage
# Out:
# 2025-04-24 12:25:37.272440: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ## Two-face Detection

# %%
import os

dir_path = "/Users/pootaatoos/networked_painting"

# %%
item = 'two_person'
img_path = f'/pic/input/{item}.jpg'
img_net = FaceImage(dir_path + img_path)

# %%
save_dir = f'/pic/output/{item}_output.jpg'
img_net.plot_network(dir_path + save_dir)

# %%
img_net.get_faces()
# Out:
# [{'id': 'face_1',
#   'bbox': [161, 273, 332, 530],
#   'landmarks': {'right_eye': [227.22166, 380.51236],
#    'left_eye': [304.44034, 378.30798],
#    'nose': [281.2528, 431.1224],
#    'mouth_right': [239.30876, 478.0347],
#    'mouth_left': [294.73752, 476.84055]}},
#  {'id': 'face_2',
#   'bbox': [581, 150, 769, 450],
#   'landmarks': {'right_eye': [628.8894, 275.52972],
#    'left_eye': [720.58563, 271.14258],
#    'nose': [676.9917, 342.34436],
#    'mouth_right': [648.33325, 392.26978],
#    'mouth_left': [711.0573, 388.76538]}}]

# %%
img_net.get_between_face_vectors()
# Out:
# {('face_1', 'face_2'): array([ 0.97307359, -0.23049468]),
#  ('face_2', 'face_1'): array([-0.97307359,  0.23049468])}

# %%
img_net.get_orientation_vectors()
# Out:
# {'face_1': array([0.99970469, 0.02430083]),
#  'face_2': array([ 0.98764743, -0.15669255])}

# %%
img_net.get_network()
# Out:
# [('face_1', 'face_2', 0.9671850173008563),
#  ('face_2', 'face_1', -0.997170424821682)]

# %% [markdown]
# ## Three-face Detection

# %%
item = 'three_person'
img_path = f'/pic/input/{item}.jpg'
img_net = FaceImage(dir_path + img_path)

# %%
save_dir = f'/pic/output/{item}_output.jpg'
img_net.plot_network(dir_path + save_dir)

# %%
img_net.get_faces()
# Out:
# [{'id': 'face_1',
#   'bbox': [200, 83, 278, 186],
#   'landmarks': {'right_eye': [229.00954, 121.107834],
#    'left_eye': [262.1085, 131.53291],
#    'nose': [242.65529, 149.2233],
#    'mouth_right': [220.22699, 157.14133],
#    'mouth_left': [247.74968, 165.8765]}},
#  {'id': 'face_2',
#   'bbox': [248, 258, 321, 349],
#   'landmarks': {'right_eye': [271.56863, 293.56976],
#    'left_eye': [303.91357, 294.00775],
#    'nose': [289.2308, 310.37537],
#    'mouth_right': [271.89056, 322.77176],
#    'mouth_left': [302.86716, 322.9772]}},
#  {'id': 'face_3',
#   'bbox': [341, 219, 420, 318],
#   'landmarks': {'right_eye': [360.2772, 259.12183],
#    'left_eye': [396.27725, 255.61078],
#    'nose': [379.16733, 274.72144],
#    'mouth_right': [365.0841, 290.5032],
#    'mouth_left': [400.20828, 287.14572]}}]

# %%
img_net.get_between_face_vectors()
# Out:
# {('face_1', 'face_2'): array([0.25997347, 0.96561576]),
#  ('face_1', 'face_3'): array([0.72608751, 0.6876023 ]),
#  ('face_2', 'face_1'): array([-0.25997347, -0.96561576]),
#  ('face_2', 'face_3'): array([ 0.93950736, -0.34252872]),
#  ('face_3', 'face_1'): array([-0.72608751, -0.6876023 ]),
#  ('face_3', 'face_2'): array([-0.93950736,  0.34252872])}

# %%
img_net.get_orientation_vectors()
# Out:
# {'face_1': array([0.77374956, 0.63349161]),
#  'face_2': array([0.24151231, 0.97039775]),
#  'face_3': array([-0.19567896,  0.98066801])}

# %%
img_net.get_network()
# Out:
# [('face_1', 'face_2', 0.8128638430122163),
#  ('face_1', 'face_3', 0.99740018095348),
#  ('face_2', 'face_1', -0.9998181590348038),
#  ('face_2', 'face_3', -0.10548650966028836),
#  ('face_3', 'face_1', -0.5322295338666782),
#  ('face_3', 'face_2', 0.5197487854733367)]

# %% [markdown]
# ## Multiple Faces

# %%
item = 'multiple_person'
img_path = f'/pic/input/{item}.jpg'
img_net = FaceImage(dir_path + img_path)

save_dir = f'/pic/output/{item}_output.jpg'
img_net.plot_network(dir_path + save_dir)

# %%
img_net.get_faces()
# Out:
# [{'id': 'face_1',
#   'bbox': [367, 264, 381, 283],
#   'landmarks': {'right_eye': [376.61374, 272.02676],
#    'left_eye': [379.13446, 271.68457],
#    'nose': [380.80957, 275.43106],
#    'mouth_right': [377.14597, 279.2654],
#    'mouth_left': [378.8646, 279.34064]}},
#  {'id': 'face_2',
#   'bbox': [456, 259, 470, 279],
#   'landmarks': {'right_eye': [459.37247, 267.05505],
#    'left_eye': [461.73648, 267.5512],
#    'nose': [457.5281, 270.94644],
#    'mouth_right': [458.92838, 274.73022],
#    'mouth_left': [460.6205, 274.86426]}},
#  {'id': 'face_3',
#   'bbox': [425, 292, 438, 306],
#   'landmarks': {'right_eye': [429.0669, 297.2442],
#    'left_eye': [435.03433, 297.18588],
#    'nose': [431.94302, 300.377],
#    'mouth_right': [429.9291, 303.455],
#    'mouth_left': [434.24973, 303.40784]}},
#  {'id': 'face_4',
#   'bbox': [126, 150, 142, 169],
#   'landmarks': {'right_eye': [128.05914, 157.58514],
#    'left_eye': [133.3439, 157.20776],
# ...

# %%
img_net.get_network()
# Out:
# [('face_1', 'face_2', 0.9996169866170977),
#  ('face_1', 'face_3', 0.9046417697247443),
#  ('face_1', 'face_4', -0.8932427877351277),
#  ('face_1', 'face_5', 0.9999981022148035),
#  ('face_1', 'face_6', 0.997606689322225),
#  ('face_1', 'face_7', -0.9999912648807524),
#  ('face_1', 'face_8', 0.8540781688573874),
#  ('face_1', 'face_9', -0.960482128390659),
#  ('face_1', 'face_10', 0.9901012550042926),
#  ('face_1', 'face_11', 0.9997034108241248),
#  ('face_1', 'face_12', -0.9873589470641903),
#  ('face_1', 'face_13', -0.7477845922334762),
#  ('face_1', 'face_14', 0.9996161898870153),
#  ('face_1', 'face_15', 0.9923608431528625),
#  ('face_1', 'face_16', 0.9862489943285032),
#  ('face_1', 'face_17', 0.9981825949331544),
#  ('face_2', 'face_1', 0.9915035152299397),
#  ('face_2', 'face_3', 0.6667599303435949),
#  ('face_2', 'face_4', 0.9710128987449366),
#  ('face_2', 'face_5', -0.9977434252091067),
#  ('face_2', 'face_6', -0.9999600081378868),
# ...
